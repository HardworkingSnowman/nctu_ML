# %%
import numpy as np
import jieba
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.utils import shuffle
from sklearn.metrics import accuracy_score
import glob, os

# %%
dfs = []
for file_num in range(0, 26):
    url = "data"+str(file_num)+"_char.csv"
    t = pd.read_csv(url, index_col=None, header=0)
    dfs.append(t)
df  = pd.concat(dfs, axis=0, ignore_index=True)
df=shuffle(df)
df.count()
# Out:
# id          123637
# category    123637
# words       123637
# dtype: int64

# %%
y = df.category
X = [str(w) for w in df.words]

# %%
le=LabelEncoder()
le.fit(df['category'].drop_duplicates(keep='first'))

y_encoder=le.transform(y)

vectorizer = CountVectorizer(analyzer='char')
X_encoder = vectorizer.fit_transform(X)

# %%
print(X[0])
print(X_encoder[0])
print(vectorizer.inverse_transform(X_encoder[0]))
print(y_encoder)
# Out:
# ['花', '邊', '聽', '到', '自', '己', '沒', '有', '上', '全', '隊', '看', '起', '來', '超', '不', '爽', '作', '者', '安', '身', '守', '份', '待', '時', '以', '動', '看', '板', '標', '題', '花', '邊', '聽', '到', '自', '己', '沒', '有', '上', '全', '隊', '看', '起', '來', '超', '不', '爽', '時', '間', '看', '起', '來', '沒', '上', '全', '感', '覺', '超', '級', '不', '爽', '的', '因', '為', '合', '約', '年', '沒', '上', '少', '了', '超', '多', '錢', '的', '湯', '知', '道', '他', '沒', '能', '入', '選', '後', '很', '沮', '喪', '今', '夏', '沒', '能', '簽', '超', '級', '頂', '薪', '了', '如', '果', '今', '年', '有', '入', '選', '或', '拿', '到', '或', '今', '夏', '跟', '勇', '士', '談', '的', '合', '約', '最', '高', '可', '達', '因', '為', '沒', '進', '也', '不', '太', '可', '能', '拿', '到', '或', '所', '以', '今', '夏', '跟', '勇', '士', '談', '的', '合', '約', '最', '多', '就', '是', '人', '要', '衣', '裝', '佛', '祖', '要', '的', '是', '金', '裝', '金', '裝', '啊', '差', '了', '萬', '美', '金', '左', '右', '能', '不', '沮', '喪', '嗎', '在', '討', '生', '活', '我', '容', '易', '嗎', '設', '計', '對', '白', '勇', '士', '老', '闆', '應', '該', '鬆', '了', '一', '小', '口', '氣', '了', '吧']
#   (0, 3)	1
#   (0, 1)	402
#   (0, 5765)	2
#   (0, 2)	200
#   (0, 0)	200
#   (0, 7047)	2
#   (0, 5516)	2
#   (0, 556)	4
#   (0, 5678)	2
#   (0, 1901)	2
#   (0, 3549)	7
#   (0, 3007)	3
#   (0, 12)	4
#   (0, 438)	3
#   (0, 7550)	2
#   (0, 4635)	4
#   (0, 6738)	3
#   (0, 230)	3
#   (0, 6741)	5
#   (0, 15)	5
#   (0, 4120)	3
#   (0, 206)	1
#   (0, 5478)	1
#   (0, 1668)	1
#   (0, 6843)	1
#   :	:
#   (0, 1896)	1
#   (0, 782)	1
#   (0, 1037)	2
#   (0, 1208)	1
#   (0, 6393)	1
#   (0, 4420)	1
#   (0, 3630)	1
#   (0, 2386)	1
#   (0, 1699)	1
#   (0, 2887)	1
#   (0, 6408)	1
#   (0, 6390)	1
#   (0, 1749)	1
#   (0, 4574)	1
#   (0, 5475)	1
#   (0, 7475)	1
#   (0, 2356)	1
#   (0, 6439)	1
#   (0, 7956)	1
#   (0, 5)	1
#   (0, 1751)	1
#   (0, 767)	1
#   (0, 3484)	1
#   (0, 817)	1
#   (0, 4)	1
# [array(['[', "'", '花', ',', ' ', '邊', '聽', '到', '自', '己', '沒', '有', '上',
#        '全', '隊', '看', '起', '來', '超', '不', '爽', '作', '者', '安', '身', '守',
#        '份', '待', '時', '以', '動', '板', '標', '題', '間', '感', '覺', '級', '的',
#        '因', '為', '合', '約', '年', '少', '了', '多', '錢', '湯', '知', '道', '他',
#        '能', '入', '選', '後', '很', '沮', '喪', '今', '夏', '簽', '頂', '薪', '如',
#        '果', '或', '拿', '跟', '勇', '士', '談', '最', '高', '可', '達', '進', '也',
#        '太', '所', '就', '是', '人', '要', '衣', '裝', '佛', '祖', '金', '啊', '差',
#        '萬', '美', '左', '右', '嗎', '在', '討', '生', '活', '我', '容', '易', '設',
#        '計', '對', '白', '老', '闆', '應', '該', '鬆', '一', '小', '口', '氣', '吧',
#        ']'], dtype='<U1')]
# [65 98 39 ... 90  6  7]

# %%
# X_train, X_test, y_train, y_test = train_test_split(X_encoder.toarray() , y_encoder, test_size=0.3, random_state=42)
test_ratio=0.3
test_size=int (test_ratio*df['category'].count())
X_train, X_test, y_train, y_test = X_encoder.toarray()[test_size:], X_encoder.toarray()[:test_size], y_encoder[test_size:], y_encoder[:test_size]

# %%
clf = GaussianNB()
clf.fit(X_train, y_train)
