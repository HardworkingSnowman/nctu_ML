# %%
import numpy as np
import jieba
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.utils import shuffle
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
from sklearn import metrics

# %%
df = pd.read_csv('toy_jieba.csv')

# %%
plt.figure(figsize=(20, 10))
plt.pie(df['category'].value_counts() , labels = df['category'].value_counts().index)
plt.axis('equal')
plt.show()

# %%
y = df.category
X = df.words

# %%
le=LabelEncoder()
le.fit(df['category'].drop_duplicates(keep='first'))

y_encoder=le.transform(y)

vectorizer = CountVectorizer()
X_encoder = vectorizer.fit_transform(X)

# %%
print(X[0])
print(X_encoder[0])
print(vectorizer.inverse_transform(X_encoder[0]))
print(y_encoder)
# Out:
# ['臉書賴', '清德', '我', '不會傷', '害民進', '黨', '作者', '阿沙布', '魯', '看板', '標題', '臉書賴', '清德', '我', '不會傷', '害民', '進黨', '時間', '引述', '大體', '老屍', '之銘言', '本周', '三民', '進黨', '中', '執會將', '再', '討論', '總統', '初選', '事宜', '我', '在', '這裡', '呼籲黨', '內', '同志', '尊重', '並維護民', '進黨', '的', '民主', '機制', '初選', '時間', '已', '一延', '再延', '如果', '又', '修改', '已經', '公告', '的', '選舉', '辦法', '對民進', '黨將', '造成', '莫大', '的', '傷害', '我', '是', '民進', '黨', '黨員', '二十五年', '來', '在', '所有', '的', '公職', '職位', '上', '努力', '表現', '因為', '我', '的', '肩膀', '上', '背', '負著民', '進黨', '的', '形象', '與', '責任', '如果', '民進', '黨', '中', '執會', '本周', '三', '真的', '再', '做出', '傷害', '黨', '的', '決定', '我', '也', '不會', '做出', '傷害', '黨', '的', '事', '因為', '我', '深愛這個', '黨', '因此', '沒', '有所', '謂', '我將', '採取', '法律', '戰', '的', '說', '法', '我', '再次', '強調民', '進黨', '的', '核心', '價值', '在', '這次', '初選中', '已', '受到', '傷害', '我', '不會', '再', '進', '一步', '傷害', '這個', '黨賴', '清德', '還好民', '進黨', '有賴', '清德', '在', '蔡', '英文', '執政下', '的', '民進', '黨', '已經', '失去', '黨魂', '和', '民主', '精神', '價值', '了', '在', '這次', '的', '總統', '初選', '過程', '中賴', '清德', '好似', '一面', '照', '妖鏡', '一場', '初', '選民進', '黨', '的', '妖怪', '們', '都', '無', '所', '遁形', '現出', '他們', '的', '原形', '蔡', '英文', '執政下', '的', '民進', '黨', '跟', '國民黨', '差別', '已', '不', '大', '了', '一直', '秉持', '尊重', '民主', '制度', '程序', '精神', '的', '賴清德', '已經', '深深', '再次', '感動', '真正', '綠營', '支持者', '的', '心', '了', '胸襟', '開闊', '光明磊落', '的', '賴清德', '了不起', '相當', '了不起', '台灣', '有', '您', '真', '好', '其實', '說', '實話', '一開始', '的', '初選', '辦法', '是', '認為', '唯一', '的', '可能', '挑戰者', '賴清德', '多次', '表示', '支持', '小英', '結果', '忽然', '又', '跑', '出來', '說', '要', '初選', '既然', '這樣', '調整', '初選', '辦法', '不算', '太過', '分', '吧', '而且', '賴清德', '如果', '真的', '領先現', '任者', '很多', '這樣', '調整', '並不會', '影響', '結果', '吧', '要是', '領先', '的', '不多賴', '清德', '打出', '的', '為', '了', '勝選', '的', '參選', '理由', '就', '不夠', '了', '如果', '現在', '還在', '抱怨', '只', '讓', '人', '感到', '你', '的', '參選', '理由', '是', '個', '屁', '而已']
#   (0, 58283)	2
#   (0, 44532)	6
#   (0, 1805)	2
#   (0, 22424)	1
#   (0, 5768)	1
#   (0, 73113)	1
#   (0, 51225)	1
#   (0, 40842)	1
#   (0, 22423)	1
#   (0, 68999)	6
#   (0, 37324)	2
#   (0, 26364)	1
#   (0, 19848)	1
#   (0, 56949)	1
#   (0, 3322)	1
#   (0, 39301)	2
#   (0, 951)	1
#   (0, 18097)	1
#   (0, 62325)	1
#   (0, 56173)	2
#   (0, 10335)	6
#   (0, 3624)	1
#   (0, 68191)	1
#   (0, 15141)	1
#   (0, 14557)	1
#   :	:
#   (0, 9765)	1
#   (0, 36568)	1
#   (0, 68018)	2
#   (0, 63374)	2
#   (0, 1950)	1
#   (0, 20259)	1
#   (0, 57106)	1
#   (0, 75504)	1
#   (0, 5192)	1
#   (0, 26989)	1
#   (0, 2275)	1
#   (0, 26870)	1
#   (0, 61617)	1
#   (0, 75501)	1
#   (0, 1610)	1
#   (0, 30436)	1
#   (0, 11704)	1
#   (0, 13161)	2
#   (0, 48464)	2
#   (0, 1612)	1
#   (0, 48238)	1
#   (0, 70053)	1
#   (0, 31219)	1
#   (0, 28804)	1
#   (0, 57130)	1
# [array(['臉書賴', '清德', '不會傷', '害民進', '作者', '阿沙布', '看板', '標題', '害民', '進黨',
#        '時間', '引述', '大體', '老屍', '之銘言', '本周', '三民', '執會將', '討論', '總統', '初選',
#        '事宜', '這裡', '呼籲黨', '同志', '尊重', '並維護民', '民主', '機制', '一延', '再延',
#        '如果', '修改', '已經', '公告', '選舉', '辦法', '對民進', '黨將', '造成', '莫大', '傷害',
#        '民進', '黨員', '二十五年', '所有', '公職', '職位', '努力', '表現', '因為', '肩膀',
#        '負著民', '形象', '責任', '執會', '真的', '做出', '決定', '不會', '深愛這個', '因此',
#        '有所', '我將', '採取', '法律', '再次', '強調民', '核心', '價值', '這次', '初選中', '受到',
#        '一步', '這個', '黨賴', '還好民', '有賴', '英文', '執政下', '失去', '黨魂', '精神', '過程',
#        '中賴', '好似', '一面', '妖鏡', '一場', '選民進', '妖怪', '遁形', '現出', '他們', '原形',
#        '國民黨', '差別', '一直', '秉持', '制度', '程序', '賴清德', '深深', '感動', '真正', '綠營',
#        '支持者', '胸襟', '開闊', '光明磊落', '了不起', '相當', '台灣', '其實', '實話', '一開始',
#        '認為', '唯一', '可能', '挑戰者', '多次', '表示', '支持', '小英', '結果', '忽然', '出來',
#        '既然', '這樣', '調整', '不算', '太過', '而且', '領先現', '任者', '很多', '並不會', '影響',
#        '要是', '領先', '不多賴', '打出', '勝選', '參選', '理由', '不夠', '現在', '還在', '抱怨',
#        '感到', '而已'], dtype='<U16')]
# [34 34 34 ... 24 24 24]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_encoder.toarray() , y_encoder, test_size=0.3, random_state=42)

# %%
clf = GaussianNB()
clf.fit(X_train, y_train)
y_predict=clf.predict(X_test)
# Out:
# 0.4364406779661017

# %%
print('Accuracy:', metrics.accuracy_score(y_test, y_predict))
print(classification_report(y_test, test_dt_prediction, [i for i in range(len(y))], y))
