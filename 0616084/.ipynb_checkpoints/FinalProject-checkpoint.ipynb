# %%
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
import random
from sklearn.metrics import accuracy_score

# %%
url='/Users/b4435242/Desktop/作業/Machine_Learning/nctu_ML/toy.csv'
df = pd.read_csv(url)

y = df.category
X = df.words

# %%
le=LabelEncoder()
le.fit(df['category'].drop_duplicates(keep='first'))

y_encoder=[]
y_encoder=le.transform(y)


X_encoder=[]
vectorizer = CountVectorizer()
X_encoder = vectorizer.fit_transform(X)

# %%
print(X[0])
print(X_encoder[0])
print(vectorizer.inverse_transform(X_encoder[0]))
# Out:
# ['問', '問卦', '問卦台', '問卦台灣', '卦', '卦台', '卦台灣', '卦台灣是', '台', '台灣', '台灣是', '台灣是不', '灣', '灣是', '灣是不', '灣是不是', '是', '是不', '是不是', '是不是該', '不', '不是', '不是該', '不是該討', '是', '是該', '是該討', '是該討論', '該', '該討', '該討論', '該討論開', '討', '討論', '討論開', '討論開放', '論', '論開', '論開放', '論開放露', '開', '開放', '開放露', '開放露奶', '放', '放露', '放露奶', '放露奶了', '露', '露奶', '露奶了', '露奶了作', '奶', '奶了', '奶了作', '奶了作者', '了', '了作', '了作者', '了作者看', '作', '作者', '作者看', '作者看板', '者', '者看', '者看板', '者看板標', '看', '看板', '看板標', '看板標題', '板', '板標', '板標題', '板標題問', '標', '標題', '標題問', '標題問卦', '題', '題問', '題問卦', '題問卦台', '問', '問卦', '問卦台', '問卦台灣', '卦', '卦台', '卦台灣', '卦台灣是', '台', '台灣', '台灣是', '台灣是不', '灣', '灣是', '灣是不', '灣是不是', '是', '是不', '是不是', '是不是該', '不', '不是', '不是該', '不是該討', '是', '是該', '是該討', '是該討論', '該', '該討', '該討論', '該討論開', '討', '討論', '討論開', '討論開放', '論', '論開', '論開放', '論開放露', '開', '開放', '開放露', '開放露奶', '放', '放露', '放露奶', '放露奶了', '露', '露奶', '露奶了', '露奶了時', '奶', '奶了', '奶了時', '奶了時間', '了', '了時', '了時間', '了時間傳', '時', '時間', '時間傳', '時間傳統', '間', '間傳', '間傳統', '間傳統中', '傳', '傳統', '傳統中', '傳統中國', '統', '統中', '統中國', '統中國封', '中', '中國', '中國封', '中國封建', '國', '國封', '國封建', '國封建思', '封', '封建', '封建思', '封建思想', '建', '建思', '建思想', '建思想用', '思', '思想', '思想用', '思想用奶', '想', '想用', '想用奶', '想用奶罩', '用', '用奶', '用奶罩', '用奶罩束', '奶', '奶罩', '奶罩束', '奶罩束縛', '罩', '罩束', '罩束縛', '罩束縛了', '束', '束縛', '束縛了', '束縛了女', '縛', '縛了', '縛了女', '縛了女性', '了', '了女', '了女性', '了女性基', '女', '女性', '女性基', '女性基本', '性', '性基', '性基本', '性基本人', '基', '基本', '基本人', '基本人權', '本', '
#   (0, 579747)	1
#   (0, 1892254)	1
#   (0, 1356266)	1
#   (0, 1356265)	1
#   (0, 1356262)	1
#   (0, 798709)	1
#   (0, 798708)	1
#   (0, 798535)	1
#   (0, 578061)	1
#   (0, 578056)	1
#   (0, 1622740)	1
#   (0, 1622739)	1
#   (0, 1622738)	1
#   (0, 1136358)	1
#   (0, 1136357)	1
#   (0, 1136347)	1
#   (0, 937208)	1
#   (0, 937207)	1
#   (0, 937206)	1
#   (0, 1847300)	1
#   (0, 1847299)	1
#   (0, 1668815)	1
#   (0, 1380874)	1
#   (0, 1380873)	1
#   (0, 1380870)	1
#   :	:
#   (0, 1636703)	3
#   (0, 1650591)	2
#   (0, 1650590)	2
#   (0, 1650589)	2
#   (0, 1002947)	2
#   (0, 1002946)	2
#   (0, 1002917)	3
#   (0, 52562)	2
#   (0, 52559)	3
#   (0, 51390)	3
#   (0, 982415)	3
#   (0, 982304)	3
#   (0, 982101)	3
#   (0, 1206079)	2
#   (0, 1206077)	2
#   (0, 1206076)	2
#   (0, 411593)	2
#   (0, 411592)	2
#   (0, 411313)	2
#   (0, 370491)	2
#   (0, 370489)	2
#   (0, 370488)	2
#   (0, 463480)	2
#   (0, 463479)	2
#   (0, 463478)	2
# [array(['奶權', '露奶權', '的露奶權', '的露奶', '的露', '性的露奶', '性的露', '性的', '女性的露',
#        '女性的', '視女性的', '視女性', '視女', '歧視女性', '歧視女', '歧視', '放歧視女', '放歧視',
#        '放歧', '開放歧視', '開放歧', '論開放歧', '真討論開', '真討論', '真討', '認真討論', '認真討',
#        '認真', '該認真討', '該認真', '該認', '是該認真', '是該認', '不是該認', '們是不是', '們是不',
#        '們是', '我們是不', '我們是', '我們', '題我們是', '題我們', '題我', '問題我們', '問題我',
#        '問題', '何問題我', '何問題', '何問', '任何問題', '任何問', '有任何問', '有任何', '有任',
#        '沒有任何', '沒有任', '卻沒有任', '卻沒有', '卻沒', '奶卻沒有', '奶卻沒', '奶卻', '露奶卻沒',
#        '露奶卻', '性露奶卻', '性露奶', '性露', '男性露奶', '男性露', '男性', '役男性露', '役男性',
#        '役男', '拘役男性', '拘役男', '拘役', '判拘役男', '判拘役', '判拘', '被判拘役', '被判拘',
#        '被判', '至被判拘', '至被判', '至被', '甚至被判', '甚至被', '甚至', '化甚至被', '化甚至',
#        '化甚', '風化甚至', '風化甚', '風化', '礙風化甚', '礙風化', '礙風', '妨礙風化', '妨礙風',
#        '為妨礙風', '為妨礙', '為妨', '視為妨礙', '視為妨', '視為', '被視為妨', '被視為', '被視',
#        '然被視為', '然被視', '然被', '竟然被視', '竟然被', '竟然', '奶竟然被', '奶竟然', '奶竟',
#        '露奶竟然', '露奶竟', '下露奶竟', '下露奶', '下露', '況下露奶', '況下露', '況下', '情況下露',
#        '情況下', '情況', '的情況下', '的情況', '的情', '人的情況', '人的情', '人的', '何人的情',
#        '何人的', '何人', '任何人的', '任何人', '任何', '礙任何人', '礙任何', '礙任', '妨礙任何',
#        '妨礙任', '妨礙', '有妨礙任', '有妨礙', '有妨', '沒有妨礙', '沒有妨', '沒有', '在沒有妨',
#        '在沒有', '在沒', '性在沒有', '性在沒', '性在', '女性在沒', '女性在', '權女性在', '權女性',
#        '權女', '主權女性', '主權女', '主權', '自主權女', '自主權', '自主', '的自主權', '的自主',
#        '的自', '中的自主', '中的自', '中的', '權中的自', '權中的', '權中', '人權中的', '人權中',
#        '人權', '本人權中', '本人權', '本人', '基本人權', '基本人', '基本', '性基本人', '性基本',
#        '性基', '女性基本', '女性基', '女性', '了女性基', '了女性', '了女', '縛了女性', '縛了女',
#        '縛了', '束縛了女', '束縛了', '束縛', '罩束縛了', '罩束縛', '罩束', '奶罩束縛', '奶罩束',
#        '奶罩', '用奶罩束', '用奶罩', '用奶', '想用奶罩', '想用奶', '想用', '思想用奶', '思想用',
#        '思想', '建思想用', '建思想', '建思', '封建思想', '封建思', '封建', '國封建思', '國封建',
#        '國封', '中國封建', '中國封', '中國', '統中國封', '統中國', '統中', '傳統中國', '傳統中',
#        '傳統', '間傳統中', '間傳統', '間傳', '時間傳統', '時間傳', '時間', '了時間傳', '了時間',
#        '了時', '奶了時間', '奶了時', '露奶了時', '題問卦台', '題問卦', '題問', '標題問卦', '標題問',
#        '標題', '板標題問', '板標題', '板標', '看板標題', '看板標', '看板', '者看板標', '者看板',
#        '者看', '作者看板', '作者看', '作者', '了作者看', '了作者', '了作', '奶了作者', '奶了作',
#        '奶了', '露奶了作', '露奶了', '露奶', '放露奶了', '放露奶', '放露', '開放露奶', '開放露',
#        '開放', '論開放露', '論開放', '論開', '討論開放', '討論開', '討論', '該討論開', '該討論',
#        '該討', '是該討論', '是該討', '是該', '不是該討', '不是該', '不是', '是不是該', '是不是',
#        '是不', '灣是不是', '灣是不', '灣是', '台灣是不', '台灣是', '台灣', '卦台灣是', '卦台灣',
#        '卦台', '問卦台灣', '問卦台', '問卦'], dtype='<U4')]

# %%
all_unique_words = vectorizer.get_feature_names()
all_unique_classes =[]
for i in y:
    if i not in all_unique_classes:
        all_unique_classes.append(i)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_encoder.toarray() , y_encoder, test_size=0.3, random_state=42)

# %%
print(X_train.toarray())

# %%
clf = GaussianNB()
clf.fit(X_train, y_train)
y_predict=clf.predict(X_test)
accuracy_score(y_test, y_predict, normalize=False)
